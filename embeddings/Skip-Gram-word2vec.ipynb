# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
cc = Counter(int_words)
tot_count = len(int_words)
thres = 1e-5
p_thres = {x: 1- np.sqrt(thres/(y/tot_count)) for x,y in cc.items()}
train_words = [word for word in int_words if p_thres[word] < random.random()]

# %%
dd2 = [int_to_vocab[d] for d in train_data[0:30]];    dd1 = [int_to_vocab[d] for d in int_words[0:30]];

# %%
dd2, dd1
# Out:
# (['anarchism',
#   'abuse',
#   'radicals',
#   'including',
#   'diggers',
#   'sans',
#   'culottes',
#   'revolution',
#   'whilst',
#   'pejorative',
#   'destroy',
#   'organization',
#   'label',
#   'anarchists',
#   'word',
#   'derived',
#   'from',
#   'archons',
#   'unnecessary',
#   'abolished',
#   'although',
#   'differing',
#   'anarchism',
#   'movements',
#   'advocate',
#   'elimination',
#   'authoritarian',
#   'anarchy',
#   'anarchists',
#   'imply'],
#  ['anarchism',
#   'originated',
#   'as',
#   'a',
#   'term',
#   'of',
#   'abuse',
#   'first',
#   'used',
#   'against',
#   'early',
#   'working',
#   'class',
#   'radicals',
#   'including',
#   'the',
#   'diggers',
#   'of',
#   'the',
#   'english',
#   'revolution',
#   'and',
#   'the',
#   'sans',
#   'culottes',
#   'of',
#   'the',
#   'french',
#   'revolution',
#   'whilst'])

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = random.randint(1,window_size+1)
    start = idx-R if (idx-R) > 0 else 0 
    stop =  idx + R
    target = set(words[start:idx] + words[idx+1:stop+1] )
    
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
bb = get_batches(train_data[:120],10,5)

# %%
"""
aa = [1,2]
aa.extend([3]) # has to be iterable inside the extend 
aa.append(4)
aa.append([5])
aa
"""
# Out:
# '\naa = [1,2]\naa.extend([3]) # has to be iterable inside the extend \naa.append(4)\naa.append([5])\naa\n'

# %%
for x,y in bb:
    print (x)
    print (y)
    break
# Out:
# [5237, 5237, 5237, 3133, 3133, 3133, 3133, 3133, 3133, 3133, 10618, 10618, 133, 133, 133, 133, 133, 133, 133, 133, 133, 27540, 27540, 27540, 27540, 27540, 27540, 27540, 27540, 27540, 15169, 15169, 15169, 15169, 15169, 15169, 15169, 15169, 63008, 63008, 63008, 63008, 63008, 63008, 854, 854, 3582, 3582, 3582, 3582, 10717]
# [10618, 3133, 133, 63008, 15169, 133, 27540, 5237, 854, 10618, 3133, 133, 63008, 15169, 10717, 27540, 5237, 854, 10618, 3133, 3582, 63008, 15169, 10717, 133, 5237, 854, 10618, 3133, 3582, 63008, 10717, 133, 27540, 854, 10618, 3133, 3582, 15169, 133, 27540, 854, 10717, 3582, 63008, 3582, 63008, 15169, 10717, 854, 3582]

# %%
# a1, b1= next(bb)

# %%
# np.vstack((a1,b1)).T

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1.0,1.0))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      embed, labels, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6402 0.3139 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5608 0.3092 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4003 0.3103 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4661 0.3055 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.3453 0.3066 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.3636 0.3098 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.3710 0.3196 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.3350 0.3298 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.2132 0.3064 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1347 0.3208 sec/batch
# Nearest to may: environments, basically, agencija, preserving, specialised, baumgarten, remains, familes,
# Nearest to not: paperwork, anabaptists, theses, chaff, designated, telescope, biathlon, elegant,
# Nearest to had: unvoiced, youthful, appropriate, vitreous, taking, repay, vocative, obtaining,
# Nearest to as: ancillon, merciless, arrest, zmir, rebecca, non, litigant, modern,
# Nearest to used: cardinals, sexy, menstrual, conglomerates, soviet, whitewash, began, serpento,
# Nearest to on: she, gattaca, visiting, tradeoffs, glutathione, peremptory, mafia, pkp,
# Nearest to s: server, guatemalan, settler, relativism, stash, europe, busting, antebellum,
# Nearest to united: converted, dwt, montt, infrastructure, concocted, adaption, definition, temper,
# Nearest to frac: parking, entirely, tricky, bananafish, legislatures, bugatti, wieman, scribal,
# Nearest to professional: plundering, dots, brabant, whitespace, smile, ailuropoda, valentinus, ovid,
# Nearest to joseph: fergusson, interdental, nonconformists, songs, excellent, ruined, nigsberg, cancellation,
# Nearest to dr: conceiving, ris, buzzing, slang, thermos, seaborg, astroturf, relegated,
# Nearest to powers: ruiz, polyhedron, imap, rockwell, italy, misfired, grove, anticonvulsants,
# Nearest to mean: farther, psychotic, richard, acacias, wavetable, satirized, einsatzgruppen, rieure,
# Nearest to prince: belial, airline, rectifiers, distance, neologism, rambouillet, perhaps, colli,
# Nearest to liberal: schubert, teamsters, vorpal, kryptonian, conger, endeavor, tess, nunnery,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1938 0.3086 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0735 0.3022 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9999 0.3035 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9432 0.3019 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8960 0.3028 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8801 0.3031 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8840 0.3039 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8805 0.3167 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8601 0.3058 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8441 0.3028 sec/batch
# Nearest to may: preserving, environments, basically, specialised, codified, respect, posed, finite,
# Nearest to not: paperwork, theses, appealed, bureaucratic, europeans, anabaptists, exemplary, byu,
# Nearest to had: unvoiced, appropriate, youthful, vitreous, repay, druze, chlorine, taking,
# Nearest to as: diode, europa, realm, ancillon, strips, cornerstone, demolition, hydrologic,
# Nearest to used: cardinals, conglomerates, menstrual, inefficient, intensely, introduces, began, photons,
# Nearest to on: visiting, tradeoffs, glutathione, she, crass, horizontally, smaller, colorless,
# Nearest to s: server, relativism, bubbles, guatemalan, absalom, defines, distinguishing, disappear,
# Nearest to united: dwt, orthodox, founding, montt, adaption, cru, departments, converted,
# Nearest to frac: mathbf, parking, legislatures, inaccurate, banach, significantly, entirely, dance,
# Nearest to professional: dots, rumsfeld, plundering, dayton, whitespace, smile, inverse, violating,
# Nearest to joseph: fergusson, kazimierz, trafficking, excellent, songs, interdental, nonconformists, inventions,
# Nearest to dr: conceiving, disjunction, animated, slang, ris, buzzing, relegated, insect,
# Nearest to powers: polyhedron, augmented, italy, ruiz, rockwell, misfired, imap, dyslexia,
# Nearest to mean: farther, richard, psychotic, needs, acacias, logistics, undetected, satirized,
# Nearest to prince: airline, neologism, belial, rambouillet, rectifiers, perhaps, distance, initials,
# Nearest to liberal: schubert, endeavor, espn, vorpal, teamsters, dropped, claiming, artillery,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8242 0.3100 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.7929 0.3040 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8107 0.3166 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7941 0.3135 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7229 0.3083 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7614 0.3105 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7528 0.3178 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7829 0.3108 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7771 0.3117 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7462 0.3122 sec/batch
# Nearest to may: basically, preserving, environments, foldoc, specialised, infty, trembling, codified,
# Nearest to not: theses, photoelectric, paperwork, exemplary, moods, bureaucratic, chaff, anabaptists,
# Nearest to had: unvoiced, appropriate, repay, hecuba, vitreous, youthful, collapsing, chlorine,
# Nearest to as: smallpox, realm, europa, freyr, goren, demolition, occidentalis, descendents,
# Nearest to used: photons, cardinals, joules, menstrual, conglomerates, southend, inefficient, isa,
# Nearest to on: visiting, tradeoffs, fijians, crass, gerrymandering, glutathione, she, smaller,
# Nearest to s: poet, fugue, tetralogy, guatemalan, macrae, busting, harold, gibraltar,
# Nearest to united: honduran, montt, orthodox, committee, founding, departments, dwt, pride,
# Nearest to frac: mathbf, x, sum, spaces, int, cdots, banach, euclidean,
# Nearest to professional: rumsfeld, vestry, ailuropoda, wwe, violating, dayton, whitespace, favored,
# Nearest to joseph: fergusson, alfredo, nonconformists, kazimierz, excellent, inventions, christina, nigsberg,
# Nearest to dr: marty, buzzing, conceiving, disjunction, animated, chill, lk, insect,
# Nearest to powers: italy, cabinet, imap, augmented, polyhedron, sidebar, ruiz, grove,
# Nearest to mean: farther, sectioned, acacias, undetected, logistics, satirized, wavetable, psychotic,
# Nearest to prince: initials, eighth, portugu, barth, eight, rambouillet, neologism, airline,
# Nearest to liberal: schubert, parties, endeavor, espn, ended, vorpal, ecumenical, fined,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7426 0.3135 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7392 0.3118 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7021 0.3067 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6772 0.3122 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6882 0.3079 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6505 0.3078 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6931 0.3099 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6890 0.3099 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6580 0.3040 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6221 0.3145 sec/batch
# Nearest to may: basically, preserving, halakhic, environments, foldoc, person, specialised, respect,
# Nearest to not: theses, bureaucratic, moods, grapheme, photoelectric, that, paperwork, anabaptists,
# Nearest to had: unvoiced, appropriate, hecuba, repay, collapsing, that, youthful, evacuating,
# Nearest to as: freyr, of, smallpox, occidentalis, the, goren, gait, cobain,
# Nearest to used: photons, cardinals, catapults, stereo, inefficient, conglomerates, joules, introduces,
# Nearest to on: smaller, iptables, bledsoe, fijians, tradeoffs, lptb, organises, visiting,
# Nearest to s: macrae, benny, tetralogy, guatemalan, starkly, a, widen, konerko,
# Nearest to united: committee, international, honduran, mahatma, founding, departments, nafta, federation,
# Nearest to frac: mathbf, int, x, infty, bernoulli, sum, log, trigonometric,
# Nearest to professional: rumsfeld, ailuropoda, wwe, vestry, school, violating, fausto, gaudy,
# Nearest to joseph: fergusson, kazimierz, alfredo, nigsberg, christina, basil, malcolm, chrysostom,
# Nearest to dr: marty, sylvian, animated, lk, annie, buzzing, marvelous, chill,
# Nearest to powers: imap, cabinet, augmented, capers, dreher, italy, misfired, diefenbaker,
# Nearest to mean: psychotic, sectioned, farther, rlc, satirized, acacias, undetected, mares,
# Nearest to prince: rambouillet, initials, wenzel, lint, bohemia, eighth, barth, mikl,
# Nearest to liberal: parties, schubert, thema, membership, teamsters, endeavor, montezuma, lazar,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6524 0.3089 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6106 0.3066 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5435 0.3049 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5926 0.3044 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5757 0.3042 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5481 0.3042 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5332 0.2204 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5361 0.3048 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5252 0.3064 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4382 0.3067 sec/batch
# Nearest to may: basically, environments, of, person, foldoc, treatments, respect, preserving,
# Nearest to not: theses, that, anabaptists, bureaucratic, moods, arbitrariness, reject, did,
# Nearest to had: that, unvoiced, the, appropriate, to, allegiance, collapsing, hecuba,
# Nearest to as: of, the, and, for, to, non, a, conversing,
# Nearest to used: photons, stereo, inserts, began, introduces, menstrual, modifier, inconsistently,
# Nearest to on: smaller, for, lptb, and, new, muppets, intellivision, photographic,
# Nearest to s: a, was, in, benny, macrae, tetralogy, ginsberg, aargau,
# Nearest to united: committee, international, broaden, mahatma, nafta, honduran, federation, founding,
# Nearest to frac: mathbf, qquad, infty, int, bernoulli, logarithm, sum, equation,
# Nearest to professional: jordan, rumsfeld, ailuropoda, bonin, chillout, vestry, wwe, school,
# Nearest to joseph: christina, alfredo, kazimierz, fergusson, austrian, basil, lars, nigsberg,
# Nearest to dr: marty, sylvian, conceiving, ris, animated, annie, chris, reunited,
# Nearest to powers: cabinet, imap, italy, dreher, avram, vested, diefenbaker, capers,
# Nearest to mean: farther, sectioned, satirized, entail, rlc, bogside, hyphens, acacias,
# Nearest to prince: rambouillet, matthias, wenzel, initials, archduke, eakins, barth, ans,
# Nearest to liberal: parties, teamsters, schubert, thema, liberalism, vorpal, governing, srp,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.3935 0.3074 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4363 0.3070 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3701 0.3060 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4507 0.3038 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4175 0.3039 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4152 0.3029 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4058 0.3057 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3214 0.3049 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4106 0.3039 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3540 0.3025 sec/batch
# Nearest to may: environments, node, basically, person, organism, respect, treatments, halakhic,
# Nearest to not: theses, moods, bureaucratic, exam, propagated, medication, that, arbitrariness,
# Nearest to had: unvoiced, appropriate, hecuba, youthful, repay, that, preferably, stopped,
# Nearest to as: of, the, and, a, for, non, to, occidentalis,
# Nearest to used: photons, denatured, cardinals, inserts, menstrual, descriptive, introduces, modifier,
# Nearest to on: smaller, connectors, new, mckusick, capitol, muppets, fuentes, fijians,
# Nearest to s: a, konerko, widen, one, by, paucity, emoticons, starkly,
# Nearest to united: international, nafta, u, committee, broaden, federation, departments, mahatma,
# Nearest to frac: mathbf, qquad, sum, infty, logarithm, trigonometric, int, bernoulli,
# Nearest to professional: school, hockey, flops, rumsfeld, leagues, vestry, teams, basketball,
# Nearest to joseph: christina, advocates, fergusson, chrysostom, jude, basil, kazimierz, clement,
# Nearest to dr: marty, ris, sylvian, residue, lopez, conceiving, annie, disjunction,
# Nearest to powers: cabinet, vested, imap, credentials, italy, deputies, lawmaking, dreher,
# Nearest to mean: farther, sectioned, rlc, satirized, psychotic, polysyllabic, entail, bogside,
# Nearest to prince: rambouillet, initials, wenzel, matthias, barth, altenberg, eakins, napoleon,
# Nearest to liberal: parties, election, labour, liberals, teamsters, membership, vorpal, srp,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3539 0.3069 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3524 0.3055 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3597 0.3064 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3229 0.3009 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3373 0.3022 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4415 0.3010 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3564 0.3005 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3173 0.3016 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3578 0.3004 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3531 0.3008 sec/batch
# Nearest to may: environments, fontsize, node, person, glancing, heritable, respect, codified,
# Nearest to not: theses, moods, exam, byu, hoods, that, appealed, exemplary,
# Nearest to had: stopped, hecuba, repay, paulist, revolted, arrived, continued, certificate,
# Nearest to as: the, and, of, a, non, to, is, for,
# Nearest to used: surnames, inkjet, photons, basque, denatured, vigesimal, inserts, meaning,
# Nearest to on: smaller, the, and, transsexualism, mckusick, it, fuentes, were,
# Nearest to s: a, starkly, lsp, one, jmu, eminem, hallucination, konerko,
# Nearest to united: international, states, departments, nafta, florida, committee, profession, membership,
# Nearest to frac: mathbf, sum, textrm, infty, logarithm, int, qquad, cos,
# Nearest to professional: rumsfeld, school, teams, flops, hockey, basketball, jordan, amateur,
# Nearest to joseph: christina, fergusson, jude, advocates, basil, mombasa, austrian, wagoner,
# Nearest to dr: sylvian, residue, lopez, marty, faults, chris, ris, actor,
# Nearest to powers: cabinet, vested, credentials, imap, deputies, lawmaking, representatives, italy,
# Nearest to mean: farther, sectioned, psychotic, rlc, undetected, acacias, satirized, entail,
# Nearest to prince: initials, empress, gemmei, napoleon, emperors, emperor, archduke, throne,
# Nearest to liberal: parties, conservatism, membership, srp, teamsters, political, vorpal, conservative,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2962 0.3023 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3536 0.3032 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3088 0.3017 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2788 0.3017 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3414 0.2997 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3365 0.3018 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3503 0.3013 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3178 0.2997 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2947 0.3019 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2981 0.2983 sec/batch
# Nearest to may: environments, person, heritable, glancing, codified, basically, andamanese, tn,
# Nearest to not: moods, appealed, but, exam, byu, signalling, with, that,
# Nearest to had: shona, repay, hannibal, continued, preferably, stopped, started, was,
# Nearest to as: and, the, of, a, to, is, in, there,
# Nearest to used: tense, english, use, meaning, inkjet, suffix, perfective, aspect,
# Nearest to on: the, it, mckusick, support, fabius, and, suction, tradeoffs,
# Nearest to s: a, one, guatemalan, tn, jmu, zero, lsp, two,
# Nearest to united: international, states, departments, u, montt, committee, honduran, idaho,
# Nearest to frac: mathbf, textrm, infty, sum, logarithm, int, ln, sqrt,
# Nearest to professional: teams, rumsfeld, school, leagues, hockey, basketball, flops, xhtml,
# Nearest to joseph: christina, fergusson, reveal, jude, mombasa, advocates, udv, nonconformists,
# Nearest to dr: ris, residue, faults, sylvian, lk, embryonic, marty, conceiving,
# Nearest to powers: cabinet, credentials, vested, deputies, dreher, lawmaking, representatives, italy,
# Nearest to mean: farther, transforms, hyphens, rlc, psychotic, sectioned, satirized, undetected,
# Nearest to prince: initials, regency, wenzel, rambouillet, anjou, gemmei, matthias, empress,
# Nearest to liberal: parties, conservatism, membership, election, liberals, vorpal, political, thema,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3618 0.3066 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2521 0.3035 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3874 0.3019 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3583 0.3010 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3802 0.3008 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2780 0.3021 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2681 0.2986 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3281 0.3005 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1716 0.3013 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2908 0.3006 sec/batch
# Nearest to may: person, glancing, environments, fontsize, heritable, basically, respect, lithograph,
# Nearest to not: exam, that, danneskj, byu, lsd, appealed, moods, exemplary,
# Nearest to had: was, repay, stopped, suffered, certificate, continued, godf, preferably,
# Nearest to as: the, and, a, to, of, in, for, koi,
# Nearest to used: tags, airstream, modifier, use, stereo, mattel, loudness, suffix,
# Nearest to on: september, august, mckusick, girlfriend, june, iptables, fabius, for,
# Nearest to s: a, zero, was, one, the, in, portrayals, two,
# Nearest to united: states, international, idaho, canada, broaden, founding, nafta, kach,
# Nearest to frac: mathbf, textrm, cdot, sqrt, theta, ln, sum, infty,
# Nearest to professional: basketball, school, hockey, seanad, indoor, teams, ncaa, jordan,
# Nearest to joseph: christina, basil, austrian, dawkins, jude, geologist, fielding, schnitzler,
# Nearest to dr: lk, ris, faults, residue, acuity, embryonic, hopper, doggystyle,
# Nearest to powers: cabinet, credentials, deputies, dreher, vested, polyhedron, attacked, sociopath,
# Nearest to mean: transforms, rlc, farther, averages, defined, hyphens, numerals, valued,
# Nearest to prince: wenzel, anjou, gemmei, initials, regency, altenberg, rambouillet, humphries,
# Nearest to liberal: parties, conservatism, liberals, liberalism, political, election, labour, conservative,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2677 0.3058 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2559 0.3004 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2677 0.1338 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1571 0.3006 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2131 0.3018 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1941 0.3045 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1936 0.3026 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1618 0.3013 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1781 0.3017 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1687 0.3018 sec/batch
# Nearest to may: environments, person, glancing, infections, fontsize, recognised, halakhic, severe,
# Nearest to not: exam, byu, appealed, propagated, hoods, that, heaps, bridgetown,
# Nearest to had: was, that, stopped, cursory, after, were, arslan, lanphier,
# Nearest to as: and, the, to, of, a, for, is, koi,
# Nearest to used: use, modifier, as, suffix, catapults, cannabis, infield, denatured,
# Nearest to on: the, it, mckusick, jul, september, new, june, almost,
# Nearest to s: a, was, in, zero, one, soufriere, finalist, aargau,
# Nearest to united: states, international, nafta, canada, u, navy, montt, honduran,
# Nearest to frac: mathbf, sqrt, textrm, theta, cdot, sum, cos, infty,
# Nearest to professional: sport, teams, school, indoor, hockey, rumsfeld, seanad, nhl,
# Nearest to joseph: dawkins, christina, bosons, basil, horkheimer, kahn, zech, fergusson,
# Nearest to dr: ris, faults, hopper, residue, lk, lockhart, doggystyle, acuity,
# Nearest to powers: credentials, cabinet, deputies, vested, polyhedron, reunification, poles, attacked,
# Nearest to mean: farther, satirized, averages, endemol, deviation, rlc, pakistani, undetected,
# Nearest to prince: wife, wenzel, anjou, altenberg, gemmei, initials, regency, louis,
# Nearest to liberal: parties, liberals, conservatism, election, labour, policies, espn, democrats,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2362 0.3056 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2003 0.3019 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2261 0.3010 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0958 0.3011 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1853 0.3022 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1293 0.3032 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1340 0.2998 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1850 0.3008 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1750 0.3034 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1428 0.3007 sec/batch
# Nearest to may: node, environments, person, heritable, no, basically, respect, treatments,
# Nearest to not: exam, to, that, it, renunciation, with, heaps, byu,
# Nearest to had: was, stopped, after, his, he, continued, arslan, suffered,
# Nearest to as: and, for, a, the, of, to, is, in,
# Nearest to used: as, use, modifier, inserts, mandatory, grunge, airstream, summa,
# Nearest to on: the, limits, bledsoe, craters, for, almost, mckusick, it,
# Nearest to s: one, a, zero, carmilla, was, two, eight, earnhardt,
# Nearest to united: states, international, nafta, canada, u, kach, ottawa, nations,
# Nearest to frac: mathbf, cdot, textrm, sqrt, ln, cos, sum, trigonometric,
# Nearest to professional: school, sport, basketball, teams, hockey, professionals, indoor, seanad,
# Nearest to joseph: advocates, bosons, dawkins, mormon, smith, fergusson, basil, jude,
# Nearest to dr: doggystyle, hopper, faults, lk, ris, lockhart, residue, nwa,
# Nearest to powers: cabinet, credentials, deputies, vested, sociopath, lawmaking, dreher, assemblies,
# Nearest to mean: farther, averages, satirized, psychotic, pseudepigrapha, deviation, undetected, rlc,
# Nearest to prince: wenzel, altenberg, initials, brunswick, regency, anjou, gemmei, antiochus,
# Nearest to liberal: parties, liberals, election, policies, democrats, ethnocentric, political, espn,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1074 0.3041 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2131 0.3006 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1816 0.3026 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1396 0.2993 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1523 0.3011 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2312 0.3013 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2369 0.3033 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1889 0.3000 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1802 0.3016 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2231 0.3006 sec/batch
# Nearest to may: fontsize, environments, node, heritable, muddled, theosophy, masculinefeminineneuter, recent,
# Nearest to not: that, have, to, of, is, renunciation, with, it,
# Nearest to had: was, stopped, after, were, been, his, started, he,
# Nearest to as: and, the, in, a, of, to, fredericton, is,
# Nearest to used: as, use, summa, latinate, duesberg, grunge, semigroup, fornax,
# Nearest to on: the, fredericton, efta, september, in, by, june, insubstantial,
# Nearest to s: one, a, was, four, three, nine, in, and,
# Nearest to united: states, international, founding, canada, nafta, u, for, kach,
# Nearest to frac: mathbf, textrm, sqrt, cdot, cos, ln, boltzmann, backslash,
# Nearest to professional: school, euphonium, hockey, sport, teams, basketball, nhl, alongside,
# Nearest to joseph: bosons, mombasa, jude, dawkins, fergusson, kirtland, horkheimer, composed,
# Nearest to dr: faults, dre, doggystyle, ris, pesticide, lk, hopper, nwa,
# Nearest to powers: vested, credentials, cabinet, representatives, monarchy, sociopath, deputies, dft,
# Nearest to mean: averages, satirized, pseudepigrapha, psychotic, farther, equinox, rlc, deviation,
# Nearest to prince: princess, anjou, wenzel, fujiwara, wife, throne, crown, queen,
# Nearest to liberal: parties, liberals, election, policies, political, ethnocentric, conservative, democrats,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2340 0.3062 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1299 0.3030 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1813 0.3000 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1572 0.3015 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1351 0.3025 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1398 0.3019 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1782 0.2997 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1526 0.3019 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2470 0.3022 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2336 0.3018 sec/batch
# Nearest to may: fontsize, faroes, person, elections, halakhic, without, policed, cockburn,
# Nearest to not: that, to, have, it, this, with, but, ddt,
# Nearest to had: was, been, that, were, after, to, his, later,
# Nearest to as: and, the, for, in, to, a, of, dredd,
# Nearest to used: use, tags, airstream, latinate, mandatory, fornax, summa, loudness,
# Nearest to on: the, in, june, by, and, march, september, november,
# Nearest to s: a, and, one, was, of, the, as, by,
# Nearest to united: states, international, u, in, canada, for, nafta, ottawa,
# Nearest to frac: mathbf, cdot, textrm, cos, sqrt, theta, ln, kx,
# Nearest to professional: hockey, school, basketball, sport, teams, seanad, xhtml, hibbert,
# Nearest to joseph: kirtland, jude, smith, bosons, mormon, wartburg, reveal, dawkins,
# Nearest to dr: dre, faults, doggystyle, lk, ris, who, nwa, hansen,
# Nearest to powers: iceman, credentials, bene, glc, impinging, sociopath, imap, juniper,
# Nearest to mean: equinox, satirized, averages, psychotic, farther, tetrahedra, rlc, beltane,
# Nearest to prince: princess, wenzel, fujiwara, kusakabe, matthias, wife, jonson, anjou,
# Nearest to liberal: parties, liberals, ethnocentric, political, election, espn, democrats, conservatism,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2133 0.3047 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.2083 0.3033 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1439 0.2998 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1502 0.2998 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0341 0.3004 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1436 0.3036 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1362 0.3011 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1761 0.3013 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1907 0.0483 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1509 0.3015 sec/batch
# Nearest to may: lithograph, penalty, hokku, person, sibm, fontsize, lovell, cockburn,
# Nearest to not: that, to, have, it, did, this, exam, been,
# Nearest to had: was, been, after, were, stopped, later, continued, until,
# Nearest to as: and, for, a, to, the, of, in, s,
# Nearest to used: use, as, tags, term, latinate, dortmund, loudness, brands,
# Nearest to on: the, in, and, june, by, a, for, march,
# Nearest to s: a, the, in, and, was, as, by, one,
# Nearest to united: states, international, nafta, u, nations, sumter, canada, virginia,
# Nearest to frac: mathbf, cdot, cos, textrm, sqrt, cdots, kx, backslash,
# Nearest to professional: school, hockey, teams, basketball, xhtml, jordan, professionals, sport,
# Nearest to joseph: kirtland, louisiane, wartburg, christina, bosons, schnitzler, fielding, jude,
# Nearest to dr: dre, faults, doggystyle, nwa, lk, embryonic, who, hansen,
# Nearest to powers: credentials, iceman, glc, vested, pursuance, cabinet, dispersed, representatives,
# Nearest to mean: equinox, averages, deviation, tetrahedra, bunter, arithmetic, defined, rlc,
# Nearest to prince: princess, wenzel, kusakabe, wife, crown, regency, gemmei, fujiwara,
# Nearest to liberal: liberals, neoliberalism, conservatism, ethnocentric, espn, parties, influential, political,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0915 0.3045 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0763 0.3028 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1122 0.2996 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0565 0.3022 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1297 0.3009 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0484 0.3011 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0573 0.3011 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1146 0.3004 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1274 0.3000 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0435 0.3019 sec/batch
# Nearest to may: specialised, treatments, acupuncture, infections, person, sibm, lithograph, without,
# Nearest to not: that, to, it, have, but, other, be, of,
# Nearest to had: was, been, that, after, were, until, as, when,
# Nearest to as: and, to, a, for, the, of, in, was,
# Nearest to used: as, in, use, it, term, a, latinate, usage,
# Nearest to on: the, and, in, it, for, two, a, september,
# Nearest to s: was, and, a, one, the, of, three, in,
# Nearest to united: states, canada, international, u, nations, zealand, for, nafta,
# Nearest to frac: cos, backslash, x, kx, sqrt, ln, tau, mappings,
# Nearest to professional: basketball, hockey, school, sport, spectator, indoor, xhtml, teams,
# Nearest to joseph: kirtland, convincing, mormon, smith, advocates, wartburg, mormons, jude,
# Nearest to dr: faults, doggystyle, dre, hopper, cop, acetylcholine, nwa, lk,
# Nearest to powers: credentials, iceman, cabinet, denoted, monarchy, glc, representatives, escape,
# Nearest to mean: equinox, bunter, beltane, averages, deviation, farther, subspecies, savanna,
# Nearest to prince: kusakabe, wenzel, antiochus, princess, holley, bathory, titanosaurus, gemmei,
# Nearest to liberal: election, mps, liberals, party, conservative, political, parties, neoliberalism,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0822 0.3061 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0219 0.3002 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0641 0.2981 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0726 0.3003 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0906 0.3004 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0553 0.3006 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1034 0.2993 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1204 0.3004 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.1365 0.3022 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0695 0.3003 sec/batch
# Nearest to may: specialised, lowlands, environments, of, sibm, masculinefeminineneuter, lithograph, fontsize,
# Nearest to not: that, to, but, this, be, with, it, have,
# Nearest to had: was, after, were, been, until, that, rommel, continued,
# Nearest to as: a, and, for, the, of, to, is, in,
# Nearest to used: as, use, it, term, english, usage, latinate, an,
# Nearest to on: the, and, in, a, it, fredericton, by, of,
# Nearest to s: a, was, and, three, of, one, as, the,
# Nearest to united: states, canada, u, us, international, war, nations, ottawa,
# Nearest to frac: ln, cos, e, sqrt, cdots, textrm, kx, backslash,
# Nearest to professional: school, xhtml, basketball, professionals, spectator, amateur, sport, euphonium,
# Nearest to joseph: mormon, fielding, kirtland, advocates, convincing, smith, jude, louisiane,
# Nearest to dr: dre, doggystyle, nwa, hansen, acetylcholine, ris, hopper, faults,
# Nearest to powers: credentials, denoted, glc, monarchy, superheroes, iceman, personified, dispersed,
# Nearest to mean: averages, equinox, bunter, deviation, beltane, tetrahedra, numerals, bocks,
# Nearest to prince: wenzel, brunswick, kusakabe, scotia, bathory, holley, matthias, vend,
# Nearest to liberal: liberals, election, conservative, mps, neoliberalism, political, parties, party,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.1003 0.3062 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1470 0.3011 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1122 0.3026 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.1590 0.3005 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.1321 0.3019 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0708 0.3004 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1107 0.2990 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.1087 0.3015 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1161 0.3011 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.1126 0.3025 sec/batch
# Nearest to may: sibm, specialised, penalty, without, masculinefeminineneuter, fontsize, brigid, severe,
# Nearest to not: but, that, this, with, to, is, have, it,
# Nearest to had: was, been, were, after, in, later, that, until,
# Nearest to as: and, the, in, of, a, is, to, for,
# Nearest to used: as, use, it, term, usage, mandatory, traditional, dortmund,
# Nearest to on: the, and, by, in, a, for, from, to,
# Nearest to s: one, and, a, zero, three, two, by, four,
# Nearest to united: states, canada, u, founding, yuma, international, ottawa, war,
# Nearest to frac: cos, ln, textrm, omega, kx, infty, sqrt, imaginary,
# Nearest to professional: school, xhtml, teams, basketball, spectator, professionals, indoor, hibbert,
# Nearest to joseph: kirtland, jude, mormon, wartburg, convincing, smith, fielding, advocates,
# Nearest to dr: dre, hansen, pesticide, nwa, doggystyle, cop, ris, faults,
# Nearest to powers: credentials, representatives, state, monarchy, cabinet, glc, wwii, representative,
# Nearest to mean: equinox, bunter, deviation, numerals, arithmetic, hours, tetrahedra, entropy,
# Nearest to prince: princess, kusakabe, fujiwara, colony, matthias, regency, bathory, crown,
# Nearest to liberal: liberals, election, mps, conservative, party, conservatism, parties, political,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0890 0.3038 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0515 0.3001 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0732 0.2994 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1002 0.3035 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0840 0.3023 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1942 0.3022 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1667 0.3018 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.1337 0.3010 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0441 0.3005 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.1271 0.3003 sec/batch
# Nearest to may: masculinefeminineneuter, donne, fontsize, brigid, similarly, without, sibilant, lithograph,
# Nearest to not: that, to, but, this, have, with, it, is,
# Nearest to had: was, been, were, haydn, that, later, after, started,
# Nearest to as: a, the, and, for, is, in, to, of,
# Nearest to used: as, use, it, term, usage, such, meaning, other,
# Nearest to on: the, in, a, march, june, september, two, and,
# Nearest to s: a, one, and, was, as, in, the, of,
# Nearest to united: states, war, u, canada, yuma, us, international, ottawa,
# Nearest to frac: cos, ln, infty, sin, lim, right, sqrt, x,
# Nearest to professional: school, xhtml, indoor, basketball, teams, amateur, spectator, euphonium,
# Nearest to joseph: kirtland, wartburg, mormon, convincing, placidia, fielding, louisiane, smith,
# Nearest to dr: dre, doggystyle, cop, faults, hansen, pesticide, coldcut, nwa,
# Nearest to powers: superheroes, mutants, credentials, personified, glc, representatives, wwii, mutant,
# Nearest to mean: equinox, entropy, arithmetic, deviation, log, hours, metonic, averages,
# Nearest to prince: kusakabe, monarchs, princess, vend, regency, anjou, bathory, fujiwara,
# Nearest to liberal: liberals, parties, neoliberalism, conservatism, conservative, ideology, mps, political,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0546 0.3065 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0745 0.3021 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0927 0.3014 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0733 0.3021 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1221 0.3014 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0840 0.2641 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0481 0.3007 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0854 0.3021 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0714 0.3013 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9957 0.3013 sec/batch
# Nearest to may: donne, without, or, masculinefeminineneuter, similarly, basotho, severe, event,
# Nearest to not: that, to, but, this, because, be, did, it,
# Nearest to had: was, that, were, after, later, been, in, it,
# Nearest to as: in, to, of, the, for, a, was, and,
# Nearest to used: as, to, use, it, dortmund, for, in, term,
# Nearest to on: the, a, and, in, for, by, to, of,
# Nearest to s: and, a, as, of, zero, the, in, was,
# Nearest to united: states, war, u, canada, ottawa, yuma, bishkek, us,
# Nearest to frac: cos, kx, sqrt, infty, omega, sin, textrm, ln,
# Nearest to professional: amateur, school, xhtml, teams, spectator, basketball, reconstructionist, euphonium,
# Nearest to joseph: kirtland, mormon, smith, wartburg, schnitzler, hanged, louisiane, three,
# Nearest to dr: dre, doggystyle, pesticide, faults, cop, nwa, mutant, endocrinology,
# Nearest to powers: superheroes, credentials, mutants, personified, representatives, state, glc, cabinet,
# Nearest to mean: deviation, arithmetic, equinox, variance, conclusive, log, entropy, subspecies,
# Nearest to prince: princess, monarchs, vend, anjou, regency, throne, matthias, humphries,
# Nearest to liberal: liberals, neoliberalism, conservatism, mps, conservative, election, ideology, parties,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0346 0.3058 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.0010 0.3021 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0513 0.3011 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0977 0.3012 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.1141 0.3001 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0425 0.3013 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9651 0.3010 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.0344 0.3017 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.0053 0.3000 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0274 0.3005 sec/batch
# Nearest to may: or, without, be, specialised, masculinefeminineneuter, severe, compelling, is,
# Nearest to not: to, that, it, but, because, have, with, this,
# Nearest to had: was, were, that, after, it, in, until, to,
# Nearest to as: the, and, for, in, a, of, to, with,
# Nearest to used: as, an, use, is, term, it, such, often,
# Nearest to on: the, in, for, and, a, two, from, to,
# Nearest to s: one, and, two, of, a, eight, zero, in,
# Nearest to united: states, u, canada, international, north, america, world, americans,
# Nearest to frac: cos, kx, infty, omega, right, textrm, vec, backslash,
# Nearest to professional: school, basketball, amateur, xhtml, professionals, teams, vocational, spectator,
# Nearest to joseph: kirtland, smith, mormon, rigdon, jude, wartburg, mormons, latter,
# Nearest to dr: dre, cop, doggystyle, endocrinology, nwa, pesticide, mutant, ris,
# Nearest to powers: superheroes, credentials, monarchy, spars, mutants, cabinet, glc, personified,
# Nearest to mean: deviation, arithmetic, equinox, numerals, conclusive, averages, frequent, beltane,
# Nearest to prince: princess, queen, bathory, vend, monarchs, newfoundland, humphries, holley,
# Nearest to liberal: liberals, conservative, mps, conservatism, democrats, parties, party, election,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0525 0.3040 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0396 0.3005 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0856 0.3011 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.1040 0.2998 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0588 0.3008 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9852 0.3017 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.1075 0.3004 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0439 0.3003 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0683 0.3018 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0349 0.2991 sec/batch
# Nearest to may: or, without, of, freemasonry, be, the, speght, event,
# Nearest to not: that, to, this, but, it, is, be, have,
# Nearest to had: was, were, that, after, until, been, later, returned,
# Nearest to as: a, the, and, in, for, to, of, is,
# Nearest to used: as, term, such, use, an, it, is, often,
# Nearest to on: the, a, for, in, it, and, of, september,
# Nearest to s: and, a, two, of, three, in, one, zero,
# Nearest to united: states, war, u, world, canada, us, yuma, americans,
# Nearest to frac: cos, vec, textrm, cdots, kx, infty, lim, tangent,
# Nearest to professional: school, teams, amateur, basketball, euphonium, spectator, percussive, wwe,
# Nearest to joseph: smith, kirtland, mormon, hydrofoil, rigdon, schnitzler, fielding, ethan,
# Nearest to dr: dre, nwa, doggystyle, ris, mutant, sheen, cop, doggy,
# Nearest to powers: state, superheroes, cabinet, representatives, mutants, appoints, credentials, declares,
# Nearest to mean: deviation, arithmetic, equinox, conclusive, variance, entropy, definiendum, ancyra,
# Nearest to prince: princess, throne, empress, crown, clan, consort, succession, miya,
# Nearest to liberal: liberals, democrats, conservatism, conservative, mps, parties, neoliberalism, election,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0819 0.3069 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0047 0.3012 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9984 0.3017 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0361 0.3027 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0908 0.3022 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0307 0.3024 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0510 0.3012 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0287 0.3029 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0131 0.2985 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.1135 0.3013 sec/batch
# Nearest to may: be, guernsey, without, or, policed, but, coincide, rohrabacher,
# Nearest to not: that, to, but, this, be, have, does, is,
# Nearest to had: was, were, after, until, the, been, that, later,
# Nearest to as: the, and, a, in, to, was, for, of,
# Nearest to used: use, it, such, as, term, for, meaning, example,
# Nearest to on: the, in, a, by, for, and, it, from,
# Nearest to s: a, of, was, and, as, one, the, two,
# Nearest to united: states, u, war, us, canada, japan, international, in,
# Nearest to frac: cos, vec, textrm, kx, right, ln, infty, lim,
# Nearest to professional: school, xhtml, teams, spectator, violating, clotting, degree, bachelor,
# Nearest to joseph: kirtland, smith, mormon, rigdon, fielding, wartburg, schnitzler, reveal,
# Nearest to dr: dre, nwa, ris, doggystyle, lk, onn, mutant, cirrhosis,
# Nearest to powers: superheroes, state, representatives, cabinet, ability, mutants, wwii, diablo,
# Nearest to mean: arithmetic, equinox, conclusive, deviation, log, tyrrhenian, hyphens, definiendum,
# Nearest to prince: princess, throne, humphries, regency, kusakabe, kotoku, holley, gemmei,
# Nearest to liberal: liberals, conservative, conservatism, ideology, neoliberalism, parties, election, political,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.0261 0.3080 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1664 0.3024 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0787 0.3011 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.1263 0.3004 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 4.0227 0.3008 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 4.0330 0.2995 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0820 0.3012 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9890 0.3047 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0847 0.3035 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 4.0542 0.3009 sec/batch
# Nearest to may: vientiane, be, guernsey, or, is, full, coincide, so,
# Nearest to not: that, but, to, it, be, because, does, did,
# Nearest to had: was, were, after, he, been, in, that, later,
# Nearest to as: the, and, a, in, of, to, for, is,
# Nearest to used: as, such, for, it, use, example, in, sometimes,
# Nearest to on: the, in, and, for, by, a, of, two,
# Nearest to s: and, a, in, the, as, of, was, two,
# Nearest to united: states, war, u, international, us, yuma, canada, nations,
# Nearest to frac: cos, right, infty, lim, kx, vec, sqrt, textrm,
# Nearest to professional: school, teams, degree, basketball, spectator, wrestler, xhtml, screenwriter,
# Nearest to joseph: kirtland, smith, mormon, rigdon, schnitzler, fielding, reveal, jude,
# Nearest to dr: dre, nwa, endocrinology, doggystyle, coney, onn, lk, who,
# Nearest to powers: superheroes, mutants, ability, mutant, iceman, abilities, phoenix, state,
# Nearest to mean: arithmetic, deviation, variance, equinox, kurtosis, log, generalized, distribution,
# Nearest to prince: princess, throne, holley, colli, regency, gemmei, humphries, abdication,
# Nearest to liberal: liberals, ideology, conservatism, neoliberalism, liberalism, conservative, deane, phonics,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 4.0923 0.3048 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 4.0577 0.1819 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 4.0455 0.3020 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 4.0378 0.3022 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 4.0477 0.3036 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 4.0046 0.3010 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 4.0124 0.3022 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 4.0222 0.3021 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 4.0116 0.3027 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 4.0212 0.3009 sec/batch
# Nearest to may: or, be, of, the, is, from, can, such,
# Nearest to not: that, to, but, it, have, did, with, of,
# Nearest to had: was, were, in, that, he, after, the, it,
# Nearest to as: a, and, in, to, the, for, of, was,
# ...
# Nearest to powers: abilities, modeled, state, delegated, republic, personified, botc, colonies,
# Nearest to mean: arithmetic, deviation, meaning, geometric, variance, entropy, interquartile, synonymous,
# Nearest to prince: princess, kusakabe, fujiwara, regency, bezprym, gemmei, fifth, glenfinnan,
# Nearest to liberal: liberals, party, democrats, conservatives, mps, parties, conservative, policies,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.0846 0.3047 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.9202 0.3020 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.9651 0.3026 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.9633 0.2999 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.9523 0.3018 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.0124 0.3009 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.0332 0.3008 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.0210 0.3014 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.0351 0.3004 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.0980 0.3014 sec/batch
# Nearest to may: or, example, can, be, not, but, to, is,
# Nearest to not: but, that, it, to, however, is, be, of,
# Nearest to had: was, were, after, when, later, returned, started, until,
# Nearest to as: a, in, of, the, and, for, is, this,
# Nearest to used: use, in, for, uses, as, often, is, a,
# Nearest to on: in, a, the, for, by, of, and, which,
# Nearest to s: of, and, a, in, as, by, two, was,
# Nearest to united: states, america, kingdom, u, war, us, north, nations,
# Nearest to frac: cos, infty, cdot, ln, sqrt, lim, observed, approx,
# Nearest to professional: amateur, wrestler, basketball, teams, school, degree, academic, voluntary,
# Nearest to joseph: smith, kirtland, aaronic, rigdon, latter, mormon, cowdery, mormons,
# Nearest to dr: professor, dre, aftermath, academy, medical, nwa, doggystyle, farrar,
# Nearest to powers: abilities, appoints, ability, delegated, botc, personified, modeled, rautha,
# Nearest to mean: arithmetic, deviation, variance, interquartile, geometric, deviations, meaning, tyrrhenian,
# Nearest to prince: princess, scotia, kusakabe, fujiwara, completes, queen, longbowmen, bezprym,
# Nearest to liberal: liberals, democrats, conservative, liberalism, ideology, conservatives, political, parties,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.9828 0.3049 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.0254 0.3030 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.0015 0.3023 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.0452 0.3010 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.0575 0.3018 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.0471 0.3018 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.0276 0.3017 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.9924 0.3016 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.0663 0.3011 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.0392 0.3015 sec/batch
# Nearest to may: or, only, but, of, not, be, from, can,
# Nearest to not: but, that, it, however, to, does, this, of,
# Nearest to had: was, were, until, after, been, later, when, in,
# Nearest to as: the, in, a, and, of, by, to, is,
# Nearest to used: for, as, it, in, use, to, often, uses,
# Nearest to on: a, the, in, for, to, and, of, which,
# Nearest to s: one, and, two, as, of, by, a, was,
# Nearest to united: states, america, u, kingdom, canada, world, countries, war,
# Nearest to frac: infty, cos, sqrt, observed, cdot, ln, equals, approx,
# Nearest to professional: wrestler, amateur, voluntary, basketball, domme, unschooling, maroon, teams,
# Nearest to joseph: smith, kirtland, aaronic, jahwist, hydrofoil, cowdery, mormons, rigdon,
# Nearest to dr: dre, professor, dogg, doggystyle, nwa, aftermath, doggy, medical,
# Nearest to powers: state, abilities, power, appoints, parliamentary, ability, botc, republic,
# Nearest to mean: arithmetic, geometric, variance, meaning, yearly, interquartile, deviation, harmonic,
# Nearest to prince: princess, fujiwara, kusakabe, crown, who, clan, nara, tenn,
# Nearest to liberal: liberals, democrats, ideology, party, parties, conservatives, political, coalition,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.0044 0.3046 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.0239 0.3022 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.9810 0.3021 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.9611 0.3000 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.0714 0.3012 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.9996 0.3034 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0903 0.3014 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.0797 0.3006 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.1028 0.3009 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.9532 0.3005 sec/batch
# Nearest to may: or, be, can, not, only, this, example, are,
# Nearest to not: that, but, it, be, have, does, actually, to,
# Nearest to had: was, were, after, later, he, when, started, soon,
# Nearest to as: the, and, a, of, to, is, in, for,
# Nearest to used: as, use, in, from, for, it, to, term,
# Nearest to on: to, and, the, of, in, a, for, with,
# Nearest to s: and, as, of, by, was, for, the, two,
# Nearest to united: states, war, america, u, us, world, kingdom, nations,
# Nearest to frac: infty, cos, cdot, sheva, privilege, e, psychoanalytical, sqrt,
# Nearest to professional: wrestler, amateur, voluntary, basketball, maroon, school, teams, trained,
# Nearest to joseph: smith, aaronic, kirtland, comforted, mormonism, mormons, hanford, reveal,
# Nearest to dr: professor, dogg, dre, medical, doggystyle, sauron, telepathic, doggy,
# Nearest to powers: abilities, phoenix, mutant, rautha, subtle, telepathic, mutants, power,
# Nearest to mean: arithmetic, geometric, log, variance, meaning, phrase, synonymous, interquartile,
# Nearest to prince: princess, fujiwara, kusakabe, who, crown, kampaku, completes, gyoku,
# Nearest to liberal: liberals, neoliberalism, ideology, democrats, liberalism, political, conservatism, gst,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.9585 0.3015 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.0517 0.2997 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.9621 0.3024 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.0554 0.3017 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.0112 0.3015 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.0373 0.3003 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.0829 0.1464 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.9576 0.3012 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.0534 0.3027 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.0524 0.3044 sec/batch
# Nearest to may: or, can, be, example, is, specific, there, are,
# Nearest to not: that, but, it, to, did, however, was, for,
# Nearest to had: was, after, were, he, when, to, later, at,
# Nearest to as: the, a, and, with, to, in, for, of,
# Nearest to used: in, as, use, an, known, term, describe, is,
# Nearest to on: the, to, for, and, in, at, a, of,
# Nearest to s: and, for, was, of, four, one, as, two,
# Nearest to united: states, kingdom, war, u, america, canada, kappa, s,
# Nearest to frac: cos, infty, sheva, lim, bremsstrahlung, sum, sqrt, ericales,
# Nearest to professional: amateur, wrestler, teams, basketball, professionals, defunct, nhl, team,
# Nearest to joseph: smith, aaronic, kirtland, comforted, joliot, mormonism, hanford, claude,
# Nearest to dr: professor, dogg, doggystyle, sauron, medical, dre, doggy, malaya,
# Nearest to powers: abilities, subtle, rautha, distinct, colonies, botc, phoenix, republic,
# Nearest to mean: arithmetic, variance, deviation, kurtosis, harmonic, meaning, geometric, timezone,
# Nearest to prince: princess, duke, wife, gemmei, kusakabe, andrei, who, belial,
# Nearest to liberal: liberals, democrats, neoliberalism, liberalism, coalition, party, conservatives, conservative,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.0157 0.3048 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.9980 0.3016 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.9729 0.3012 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.9811 0.3017 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.0187 0.3006 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.9993 0.3002 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.0923 0.3014 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.9229 0.3019 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.9922 0.3013 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.9750 0.3012 sec/batch
# Nearest to may: or, from, can, are, is, be, example, to,
# Nearest to not: but, it, that, most, does, to, for, still,
# Nearest to had: was, were, after, later, been, he, have, returned,
# Nearest to as: the, in, a, and, for, to, is, of,
# Nearest to used: as, for, term, an, known, in, use, is,
# Nearest to on: to, in, the, for, this, a, at, from,
# Nearest to s: and, of, in, as, a, for, the, with,
# Nearest to united: states, kingdom, america, nations, u, canada, north, countries,
# Nearest to frac: cos, infty, quad, sum, bremsstrahlung, sheva, pulsation, argand,
# Nearest to professional: amateur, voluntary, basketball, wrestler, professionals, profession, certification, unschooling,
# Nearest to joseph: smith, latter, aaronic, kirtland, mormonism, mormon, mormons, jr,
# Nearest to dr: professor, silkworth, medical, chr, dogg, observatory, malaya, dato,
# Nearest to powers: abilities, power, distinct, veto, empowered, appoints, state, subtle,
# Nearest to mean: variance, arithmetic, deviation, kurtosis, interquartile, harmonic, word, meaning,
# Nearest to prince: princess, scotia, kusakabe, bishop, completes, screams, who, browski,
# Nearest to liberal: liberals, democrats, conservatives, party, conservative, liberalism, mps, coalition,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.9435 0.3030 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.0076 0.3009 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.0102 0.3024 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.0235 0.3022 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.0129 0.2992 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.1010 0.3012 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.0339 0.3023 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.9827 0.3023 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.9976 0.3001 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.9971 0.3018 sec/batch
# Nearest to may: or, is, of, be, a, from, not, this,
# Nearest to not: but, that, if, to, does, it, this, for,
# Nearest to had: was, were, later, he, been, until, after, returned,
# Nearest to as: a, and, the, in, for, of, an, this,
# Nearest to used: as, use, in, for, term, the, a, an,
# Nearest to on: a, the, of, for, and, by, to, in,
# Nearest to s: and, as, two, a, for, an, three, one,
# Nearest to united: states, america, kingdom, canada, nations, countries, s, us,
# Nearest to frac: cos, infty, equation, sum, sheva, tagliatelle, e, argand,
# Nearest to professional: amateur, teams, voluntary, barry, profession, football, certification, tools,
# Nearest to joseph: smith, aaronic, kirtland, cowdery, mormon, jr, mormonism, hydrofoil,
# Nearest to dr: dogg, dre, observatory, doggy, nwa, doggystyle, medical, aftermath,
# Nearest to powers: power, abilities, government, formally, distinct, and, state, prime,
# Nearest to mean: deviation, variance, arithmetic, kurtosis, word, staat, meaning, etymology,
# Nearest to prince: princess, throne, empress, emperor, soga, son, ruler, daughter,
# Nearest to liberal: liberals, democrats, conservatives, liberalism, conservative, party, ideology, parties,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.0695 0.3048 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.0112 0.2995 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.9676 0.3020 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.0051 0.3012 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.0575 0.3013 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.0191 0.3014 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.9876 0.2995 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.0339 0.3006 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.9865 0.3011 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.9776 0.2995 sec/batch
# Nearest to may: or, be, from, to, this, the, of, can,
# Nearest to not: to, that, this, for, be, but, have, there,
# Nearest to had: was, were, after, later, been, with, until, that,
# Nearest to as: the, and, in, a, for, of, is, by,
# Nearest to used: as, for, use, in, well, to, from, a,
# Nearest to on: the, of, for, and, to, a, which, in,
# Nearest to s: and, the, a, one, as, of, for, by,
# Nearest to united: states, kingdom, u, us, america, nations, countries, in,
# Nearest to frac: cos, infty, equation, e, sum, isospin, cdots, p,
# Nearest to professional: teams, amateur, voluntary, football, basketball, wrestler, certification, team,
# Nearest to joseph: smith, chopin, jahwist, kirtland, aaronic, analytic, mormon, bucher,
# Nearest to dr: dre, dogg, doggystyle, snoop, nwa, observatory, cop, medical,
# Nearest to powers: abilities, power, constitution, rautha, benevolent, botc, rebooted, distinct,
# Nearest to mean: arithmetic, deviation, variance, unit, harmonic, meaning, kurtosis, synonymous,
# Nearest to prince: princess, empress, kusakabe, soga, throne, daughter, tenn, gyoku,
# Nearest to liberal: liberals, democrats, conservatives, conservative, ideology, coalition, liberalism, political,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.0100 0.3044 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.0125 0.3030 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.1109 0.3016 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.1222 0.3025 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.0629 0.3004 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.0077 0.3013 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.9370 0.2998 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.0000 0.3000 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.8882 0.3002 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.1367 0.3016 sec/batch
# Nearest to may: or, be, of, is, from, the, some, any,
# Nearest to not: that, does, to, but, because, did, have, some,
# Nearest to had: was, were, after, been, with, started, later, in,
# Nearest to as: the, in, by, for, and, was, to, a,
# Nearest to used: as, in, use, for, term, using, known, usage,
# Nearest to on: the, by, for, and, to, of, a, this,
# Nearest to s: in, of, the, for, a, as, three, and,
# Nearest to united: states, u, kingdom, us, of, war, north, nations,
# Nearest to frac: cos, infty, lim, suppose, equation, constant, cockatoo, e,
# Nearest to professional: wrestler, amateur, football, teams, kocher, american, basketball, barry,
# Nearest to joseph: smith, aaronic, kirtland, latter, bucher, mormons, mormonism, schnitzler,
# Nearest to dr: dre, medical, dogg, silkworth, doggystyle, doggy, snoop, mementos,
# Nearest to powers: abilities, rebooted, mutants, mgn, subtle, power, repelling, rautha,
# Nearest to mean: arithmetic, variance, deviation, harmonic, is, interquartile, kurtosis, unit,
# Nearest to prince: princess, empress, kusakabe, soga, gemmei, kotoku, gyoku, grand,
# Nearest to liberal: liberals, democrats, ideology, conservatives, conservative, neoliberalism, liberalism, political,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.0164 0.3050 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.0655 0.3016 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %% [markdown]
# embed_tsne = tsne.fit_transform(random.random(63000,200))

# %%
embed_tsne = tsne.fit_transform(np.random.random((63000,200)))

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
